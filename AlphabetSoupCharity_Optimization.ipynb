# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler,OneHotEncoder
import pandas as pd
import tensorflow as tf

#  Import and read the charity_data.csv.
import pandas as pd 
application_df = pd.read_csv("charity_data.csv")
application_df.head()
# Out:
#         EIN                                      NAME APPLICATION_TYPE  \
# 0  10520599              BLUE KNIGHTS MOTORCYCLE CLUB              T10
# 1  10531628    AMERICAN CHESAPEAKE CLUB CHARITABLE TR               T3
# 2  10547893        ST CLOUD PROFESSIONAL FIREFIGHTERS               T5
# 3  10553066            SOUTHSIDE ATHLETIC ASSOCIATION               T3
# 4  10556103  GENETIC RESEARCH INSTITUTE OF THE DESERT               T3
#
#         AFFILIATION CLASSIFICATION      USE_CASE  ORGANIZATION  STATUS  \
# 0       Independent          C1000    ProductDev   Association       1
# 1       Independent          C2000  Preservation  Co-operative       1
# 2  CompanySponsored          C3000    ProductDev   Association       1
# 3  CompanySponsored          C2000  Preservation         Trust       1
# 4       Independent          C1000     Heathcare         Trust       1
#
#       INCOME_AMT SPECIAL_CONSIDERATIONS  ASK_AMT  IS_SUCCESSFUL
# 0              0                      N     5000              1
# 1         1-9999                      N   108590              1
# 2              0                      N     5000              0
# 3    10000-24999                      N     6692              1
# 4  100000-499999                      N   142590              1

# %%
# Drop the non-beneficial ID columns, 'EIN','NAME','STATUS','SPECIAL_CONSIDERATIONS'. Reduce one additional input variable.
application_df= application_df.drop(['EIN', 'NAME', 'STATUS','SPECIAL_CONSIDERATIONS'],1)
application_df.head()
# Out:
# <ipython-input-2-fcf1cacd74ab>:2: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only
#   application_df= application_df.drop(['EIN', 'NAME', 'STATUS','SPECIAL_CONSIDERATIONS'],1)
#   APPLICATION_TYPE       AFFILIATION CLASSIFICATION      USE_CASE  \
# 0              T10       Independent          C1000    ProductDev
# 1               T3       Independent          C2000  Preservation
# 2               T5  CompanySponsored          C3000    ProductDev
# 3               T3  CompanySponsored          C2000  Preservation
# 4               T3       Independent          C1000     Heathcare
#
#    ORGANIZATION     INCOME_AMT  ASK_AMT  IS_SUCCESSFUL
# 0   Association              0     5000              1
# 1  Co-operative         1-9999   108590              1
# 2   Association              0     5000              0
# 3         Trust    10000-24999     6692              1
# 4         Trust  100000-499999   142590              1

# %%
# Bucket APPLICATION_TYPE
application_counts = application_df["APPLICATION_TYPE"].value_counts()

# Determine which values to replace if counts are less than 500
replace_application = list(application_counts[application_counts < 500].index)

# Replace in dataframe
for app in replace_application:
    application_df["APPLICATION_TYPE"] = application_df["APPLICATION_TYPE"].replace(app, "Other")

# Bucket CLASSIFICATION
classification_counts = application_df["CLASSIFICATION"].value_counts()

# Determine which values to replace if counts are less than 1800
replace_class = list(classification_counts[classification_counts < 1800].index)

# Replace in dataframe
for cls in replace_class:
    application_df["CLASSIFICATION"] = application_df["CLASSIFICATION"].replace(cls, "Other")

# Generate our categorical variable lists
application_cat = list(application_df.dtypes[application_df.dtypes == "object"].index)

# Create a OneHotEncoder instance
enc = OneHotEncoder(sparse=False)

# Fit and transform the OneHotEncoder using the categorical variable list
encode_df = pd.DataFrame(enc.fit_transform(application_df[application_cat]))

# Add the encoded variable names to the dataframe
encode_df.columns = enc.get_feature_names(application_cat)

# Merge one-hot encoded features and drop the originals
application_df = application_df.merge(encode_df, left_index=True, right_index=True)
application_df = application_df.drop(labels=application_cat, axis=1)
# Out:
# /usr/local/lib/python3.8/dist-packages/sklearn/utils/deprecation.py:87: FutureWarning: Function get_feature_names is deprecated; get_feature_names is deprecated in 1.0 and will be removed in 1.2. Please use get_feature_names_out instead.
#   warnings.warn(msg, category=FutureWarning)

# %%
# Split our preprocessed data into our features and target arrays
y = application_df["IS_SUCCESSFUL"].values.reshape(-1, 1)
X = application_df.drop("IS_SUCCESSFUL", axis=1).values

# Split the preprocessed data into a training and testing dataset
X_train, X_test, y_train, y_test = train_test_split(X, y)

# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
# Define the model - deep neural net, i.e., the number of input features and hidden nodes for each layer. Increase the number of hidden layers to 3.

number_input_features = len(X_train_scaled[0])
hidden_nodes_layer1 = 80
hidden_nodes_layer2 = 50
hidden_nodes_layer3 = 30

# Number_input_features
nn_inc_epochs = tf.keras.models.Sequential()

# First hidden layer
nn_inc_epochs.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="relu"))

# Second hidden layer
nn_inc_epochs.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Third hidden layer
nn_inc_epochs.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="sigmoid"))

# Output layer
nn_inc_epochs.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_inc_epochs.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense (Dense)               (None, 80)                3280
#
#  dense_1 (Dense)             (None, 50)                4050
#
#  dense_2 (Dense)             (None, 30)                1530
#
#  dense_3 (Dense)             (None, 1)                 31
#
# =================================================================
# Total params: 8,891
# Trainable params: 8,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_inc_epochs.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the Model
fit_model_inc_epochs = nn_inc_epochs.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5695 - accuracy: 0.7209
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5538 - accuracy: 0.7300
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5522 - accuracy: 0.7306
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5501 - accuracy: 0.7297
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5486 - accuracy: 0.7305
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5483 - accuracy: 0.7311
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5471 - accuracy: 0.7338
# Epoch 8/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5467 - accuracy: 0.7325
# Epoch 9/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5461 - accuracy: 0.7323
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5449 - accuracy: 0.7333
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5446 - accuracy: 0.7332
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5441 - accuracy: 0.7328
# Epoch 13/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5434 - accuracy: 0.7342
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5436 - accuracy: 0.7342
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5431 - accuracy: 0.7335
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7353
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5424 - accuracy: 0.7348
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5420 - accuracy: 0.7354
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5421 - accuracy: 0.7344
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5413 - accuracy: 0.7358
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5416 - accuracy: 0.7344
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5410 - accuracy: 0.7357
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5411 - accuracy: 0.7351
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5405 - accuracy: 0.7367
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5404 - accuracy: 0.7352
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5398 - accuracy: 0.7352
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5398 - accuracy: 0.7359
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5394 - accuracy: 0.7359
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5396 - accuracy: 0.7365
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7358
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5389 - accuracy: 0.7353
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5390 - accuracy: 0.7363
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5383 - accuracy: 0.7371
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5384 - accuracy: 0.7364
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5381 - accuracy: 0.7371
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7364
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5378 - accuracy: 0.7366
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5374 - accuracy: 0.7380
# Epoch 39/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5373 - accuracy: 0.7375
# Epoch 40/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5369 - accuracy: 0.7380
# Epoch 41/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5371 - accuracy: 0.7362
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5367 - accuracy: 0.7386
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5368 - accuracy: 0.7368
# Epoch 44/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7374
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7376
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5361 - accuracy: 0.7376
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5359 - accuracy: 0.7379
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7380
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5353 - accuracy: 0.7383
# Epoch 50/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5356 - accuracy: 0.7381
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7382
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5352 - accuracy: 0.7382
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7381
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7383
# Epoch 55/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7390
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7392
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7386
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7374
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7388
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5340 - accuracy: 0.7391
# Epoch 61/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7397
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7380
# Epoch 63/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5341 - accuracy: 0.7375
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7386
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7387
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7384
# Epoch 67/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5335 - accuracy: 0.7384
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7394
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5334 - accuracy: 0.7390
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7392
# Epoch 71/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5328 - accuracy: 0.7386
# Epoch 72/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5332 - accuracy: 0.7392
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7391
# Epoch 74/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5328 - accuracy: 0.7396
# Epoch 75/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5328 - accuracy: 0.7401
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5326 - accuracy: 0.7392
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5327 - accuracy: 0.7389
# Epoch 78/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7391
# Epoch 79/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5331 - accuracy: 0.7391
# Epoch 80/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5323 - accuracy: 0.7402
# Epoch 81/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7388
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7395
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7389
# Epoch 84/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7402
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5323 - accuracy: 0.7388
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7396
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5320 - accuracy: 0.7393
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7394
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5323 - accuracy: 0.7397
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7397
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7400
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7396
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7391
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.7395
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5319 - accuracy: 0.7393
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7390
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.7403
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7392
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7396
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7399

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_inc_epochs.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5677 - accuracy: 0.7297 - 223ms/epoch - 832us/step
# Loss: 0.5677396059036255, Accuracy: 0.72967928647995

# %%
# Changing activation function from relu to tanh

# %%
# Changing Activation Function: try tanh to handle negative inputs in X_train_scaled
nn_tanh = tf.keras.models.Sequential()

# First hidden layer
nn_tanh.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, input_dim=number_input_features, activation="tanh"))

# Second hidden layer
nn_tanh.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="tanh"))

# Third hidden layer
nn_tanh.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="tanh"))

# Output layer
nn_tanh.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_tanh.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_11 (Dense)            (None, 80)                3280
#
#  dense_12 (Dense)            (None, 50)                4050
#
#  dense_13 (Dense)            (None, 30)                1530
#
#  dense_14 (Dense)            (None, 1)                 31
#
# =================================================================
# Total params: 8,891
# Trainable params: 8,891
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile the model
nn_tanh.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
# Train the Model
fit_model_tanh = nn_tanh.fit(X_train_scaled, y_train, epochs=100)
# Out:
# Epoch 1/100
# 804/804 [==============================] - 2s 1ms/step - loss: 0.5686 - accuracy: 0.7231
# Epoch 2/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5560 - accuracy: 0.7286
# Epoch 3/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5533 - accuracy: 0.7296
# Epoch 4/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5507 - accuracy: 0.7288
# Epoch 5/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5491 - accuracy: 0.7291
# Epoch 6/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5475 - accuracy: 0.7308
# Epoch 7/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5467 - accuracy: 0.7309
# Epoch 8/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5453 - accuracy: 0.7327
# Epoch 9/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5447 - accuracy: 0.7325
# Epoch 10/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5439 - accuracy: 0.7331
# Epoch 11/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5436 - accuracy: 0.7336
# Epoch 12/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5425 - accuracy: 0.7334
# Epoch 13/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5425 - accuracy: 0.7336
# Epoch 14/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5419 - accuracy: 0.7339
# Epoch 15/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5412 - accuracy: 0.7343
# Epoch 16/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5409 - accuracy: 0.7352
# Epoch 17/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5401 - accuracy: 0.7361
# Epoch 18/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5400 - accuracy: 0.7353
# Epoch 19/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5395 - accuracy: 0.7369
# Epoch 20/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5392 - accuracy: 0.7361
# Epoch 21/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5387 - accuracy: 0.7365
# Epoch 22/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5381 - accuracy: 0.7381
# Epoch 23/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5380 - accuracy: 0.7370
# Epoch 24/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5382 - accuracy: 0.7366
# Epoch 25/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5375 - accuracy: 0.7368
# Epoch 26/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5372 - accuracy: 0.7357
# Epoch 27/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5370 - accuracy: 0.7381
# Epoch 28/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5365 - accuracy: 0.7381
# Epoch 29/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5362 - accuracy: 0.7381
# Epoch 30/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5363 - accuracy: 0.7380
# Epoch 31/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5364 - accuracy: 0.7388
# Epoch 32/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5360 - accuracy: 0.7372
# Epoch 33/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5357 - accuracy: 0.7392
# Epoch 34/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5355 - accuracy: 0.7386
# Epoch 35/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5352 - accuracy: 0.7386
# Epoch 36/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5350 - accuracy: 0.7381
# Epoch 37/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5349 - accuracy: 0.7383
# Epoch 38/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7393
# Epoch 39/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7381
# Epoch 40/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5344 - accuracy: 0.7383
# Epoch 41/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5346 - accuracy: 0.7392
# Epoch 42/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5345 - accuracy: 0.7380
# Epoch 43/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5342 - accuracy: 0.7388
# Epoch 44/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5339 - accuracy: 0.7402
# Epoch 45/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5338 - accuracy: 0.7393
# Epoch 46/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5338 - accuracy: 0.7389
# Epoch 47/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7402
# Epoch 48/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5337 - accuracy: 0.7399
# Epoch 49/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5335 - accuracy: 0.7391
# Epoch 50/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5333 - accuracy: 0.7390
# Epoch 51/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5332 - accuracy: 0.7399
# Epoch 52/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5336 - accuracy: 0.7402
# Epoch 53/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7396
# Epoch 54/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7394
# Epoch 55/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5329 - accuracy: 0.7396
# Epoch 56/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5329 - accuracy: 0.7397
# Epoch 57/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5330 - accuracy: 0.7399
# Epoch 58/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5328 - accuracy: 0.7401
# Epoch 59/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5329 - accuracy: 0.7395
# Epoch 60/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5328 - accuracy: 0.7399
# Epoch 61/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7396
# Epoch 62/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5326 - accuracy: 0.7405
# Epoch 63/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5323 - accuracy: 0.7406
# Epoch 64/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5325 - accuracy: 0.7402
# Epoch 65/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5324 - accuracy: 0.7400
# Epoch 66/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5322 - accuracy: 0.7399
# Epoch 67/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7404
# Epoch 68/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5319 - accuracy: 0.7395
# Epoch 69/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7398
# Epoch 70/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7394
# Epoch 71/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5318 - accuracy: 0.7392
# Epoch 72/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5321 - accuracy: 0.7399
# Epoch 73/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.7409
# Epoch 74/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5325 - accuracy: 0.7403
# Epoch 75/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5317 - accuracy: 0.7400
# Epoch 76/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.7395
# Epoch 77/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5317 - accuracy: 0.7399
# Epoch 78/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5318 - accuracy: 0.7404
# Epoch 79/100
# 804/804 [==============================] - 2s 2ms/step - loss: 0.5316 - accuracy: 0.7402
# Epoch 80/100
# 804/804 [==============================] - 2s 3ms/step - loss: 0.5314 - accuracy: 0.7401
# Epoch 81/100
# 804/804 [==============================] - 1s 2ms/step - loss: 0.5314 - accuracy: 0.7406
# Epoch 82/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.7399
# Epoch 83/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7403
# Epoch 84/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5314 - accuracy: 0.7405
# Epoch 85/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.7406
# Epoch 86/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5316 - accuracy: 0.7397
# Epoch 87/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7406
# Epoch 88/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7400
# Epoch 89/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7397
# Epoch 90/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5319 - accuracy: 0.7400
# Epoch 91/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5315 - accuracy: 0.7405
# Epoch 92/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5314 - accuracy: 0.7401
# Epoch 93/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7402
# Epoch 94/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5313 - accuracy: 0.7406
# Epoch 95/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7392
# Epoch 96/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5308 - accuracy: 0.7404
# Epoch 97/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7402
# Epoch 98/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5310 - accuracy: 0.7400
# Epoch 99/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5308 - accuracy: 0.7408
# Epoch 100/100
# 804/804 [==============================] - 1s 1ms/step - loss: 0.5312 - accuracy: 0.7404

# %%
# Evaluate the model using the test data
model_loss, model_accuracy = nn_tanh.evaluate(X_test_scaled, y_test, verbose=2)
print(f"Loss: {model_loss}, Accuracy: {model_accuracy}")
# Out:
# 268/268 - 0s - loss: 0.5600 - accuracy: 0.7261 - 317ms/epoch - 1ms/step
# Loss: 0.5599533915519714, Accuracy: 0.726064145565033

# %%
# Export and save model to HDF5 file
nn_tanh.save("AlphabetSoupCharity_Optimization.h5")
